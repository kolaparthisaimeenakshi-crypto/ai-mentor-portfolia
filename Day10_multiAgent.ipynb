# %% [markdown]
# <a href="https://colab.research.google.com/github/kolaparthisaimeenakshi-crypto/ai-mentor-portfolia/blob/main/Day10_multiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q "numpy<2.0"
# !pip install -q --upgrade crewai litellm chromadb sentence-transformers crewai-tools
# !pip install -q google-generativeai==0.7.1
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.9/163.9 kB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.3/718.3 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 19.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.34.1 requires protobuf<6.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-api>=1.35.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# google-adk 1.29.0 requires google-genai<2.0.0,>=1.64.0, but you have google-genai 2.7.0 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-exporter-otlp-proto-http>=1.36.0, but you have opentelemetry-exporter-otlp-proto-http 1.34.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.34.1 which is incompatible.
# wandb 0.27.0 requires click>=8.2.0, but you have click 8.1.8 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# tensorflow 2.20.0 requires protobuf>=5.28.0, but you have protobuf 4.25.9 which is incompatible.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process

print("CrewAI imported successfully")
# Out:
# 05:20:14 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 05:20:14 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# CrewAI imported successfully

# %%
llm = "gemini/gemini-2.5-flash"

# %%
researcher = Agent(
    role="Placement Researcher",
    goal="Compile concise, factual placement-prep notes for B.Tech students",
    backstory="You are a research analyst who prepares short factual placement briefs in bullet form.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Researcher agent created")
# Out:
# Researcher agent created

# %%
writer = Agent(
    role="Placement Brief Writer",
    goal="Convert research notes into a clean 1-page placement brief in markdown",
    backstory="You write clear student-friendly placement briefs with headings and actionable takeaways.",
    llm=llm,
    verbose=True,
    allow_delegation=False,
)

print("Writer agent created")
# Out:
# Writer agent created

# %%
research_task = Task(
    description=(
        "Research TCS Digital placement preparation for B.Tech students. "
        "Include hiring process, technical stack, eligibility, recent hiring trends, "
        "and preparation tips. Give 3-5 bullets per section."
    ),
    agent=researcher,
    expected_output=(
        "Markdown bullet list with 5 sections: Hiring Process, Technical Stack, "
        "Eligibility, Recent Hiring Trends, Prep Tips."
    ),
)

print("Research task created")
# Out:
# Research task created

# %%
write_task = Task(
    description=(
        "Using the research notes, produce a 1-page placement brief for B.Tech students. "
        "Use markdown format. Include a 3-line opening hook, 5 clear sections, "
        "and a 3-line closing call-to-action."
    ),
    agent=writer,
    expected_output='1-page markdown brief titled "TCS Digital — Placement Prep Brief".',
)

print("Writer task created")
# Out:
# Writer task created

# %%
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
    process=Process.sequential,
    verbose=True,
)

print("Crew created successfully")
# Out:
# Crew created successfully

# %%
result = await crew.kickoff_async()

print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: d3250424-c609-4082-a050-64ae135407c3                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  ID: 8a25b2da-c01b-4e2f-a08c-15832f964ff8                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_and_parse: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 503 - This model is currently experiencing high demand. Spikes in demand are   │
# │  usually temporary. Please try again later.                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a placement brief for TCS Digital preparation for B.Tech students:                                      │
# │                                                                                                                 │
# │  ### Hiring Process                                                                                             │
# │  *   **Online Assessment:** Typically consists of advanced quantitative aptitude, verbal ability, and           │
# │  two-to-three advanced coding questions (often involving DSA concepts).                                         │
# │  *   **Technical Interview:** Focuses on in-depth DSA, core computer science subjects (OS, DBMS, OOPS, CN),     │
# │  project discussions, and problem-solving scenarios.                                                            │
# │  *   **Managerial Interview (Optional):** May assess project management skills, leadership potential, and       │
# │  ability to handle real-world challenges.                                                                       │
# │  *   **HR Interview:** Evaluates communication skills, cultural fit, career aspirations, and basic HR           │
# │  compliance checks.                                                                                             │
# │                                                                                                                 │
# │  ### Technical Stack                                                                                            │
# │  *   **Programming Languages:** Strong proficiency in at least one modern language like Java, Python, C++, or   │
# │  C# is essential.                                                                                               │
# │  *   **Data Structures & Algorithms:** In-depth knowledge and application of advanced DSA concepts are crucial  │
# │  for coding rounds and technical interviews.                                                                    │
# │  *   **Web Technologies:** Understanding of HTML, CSS, JavaScript, and familiarity with frameworks (e.g.,       │
# │  React, Angular, Node.js) is often expected for specific roles.                                                 │
# │  *   **Databases & Cloud:** Basic knowledge of SQL/NoSQL databases and familiarity with cloud platforms (AWS,   │
# │  Azure, GCP) can be a significant advantage.                                                                    │
# │  *   **Core CS Fundamentals:** Solid grasp of Operating Systems, Database Management Systems, Object-Oriented   │
# │  Programming (OOPs), and Computer Networks.                                                                     │
# │                                                                                                                 │
# │  ### Eligibility                                                                                                │
# │  *   **Academic Qualification:** Typically B.E./B.Tech/M.E./M.Tech/MCA/M.Sc in relevant streams (CS, IT, ECE,   │
# │  EEE, etc.).                                                                                                    │
# │  *   **Academic Percentage:** Generally, a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and Graduation     │
# │  (or Post-Graduation).                                                                                          │
# │  *   **Backlogs:** Usually no active backlogs allowed at the time of application or joining.                    │
# │  *   **Gap in Education:** A maximum permissible gap of 1-2 years in academic career is often specified.        │
# │                                                                                                                 │
# │  ### Recent Hiring Trends                                                                                       │
# │  *   **Focus on Niche Skills:** Increased demand for candidates with skills in AI/ML, Data Science, Cloud       │
# │  Computing, Cybersecurity, and IoT.                                                                             │
# │  *   **Advanced Problem-Solving:** Higher emphasis on practical application of coding and advanced              │
# │  problem-solving skills over theoretical knowledge.                                                             │
# │  *   **Specialized Roles:** Hiring for specific roles such as Full Stack Developer, Data Engineer, Cloud        │
# │  Engineer, AI/ML Engineer, rather than generalist profiles.                                                     │
# │  *   **Higher Compensation:** TCS Digital offers significantly higher compensation packages compared to TCS     │
# │  Ninja, targeting top-tier talent.                                                                              │
# │  *   **Virtual Recruitment:** The entire hiring process, including assessments and interviews, is               │
# │  predominantly conducted online.                                                                                │
# │                                                                                                                 │
# │  ### Prep Tips                                                                                                  │
# │  *   **Master DSA:** Dedicate significant time to practicing Data Structures and Algorithms; solve              │
# │  medium-to-hard problems on platforms like LeetCode, HackerRank, and GeeksforGeeks.                             │
# │  *   **Choose a Core Language:** Become highly proficient in one programming language (Java/Python/C++) and     │
# │  understand its advanced features and libraries.                                                                │
# │  *   **Build Projects:** Develop personal projects that demonstrate your skills in relevant technologies or     │
# │  use advanced DSA concepts; be ready to explain them thoroughly.                                                │
# │  *   **Practice Mock Interviews:** Participate in mock technical interviews to improve your problem-solving     │
# │  under pressure and articulate your thought process clearly.                                                    │
# │  *   **Strengthen CS Fundamentals:** Revise core computer science subjects (OS, DBMS, OOPS, CN) thoroughly, as  │
# │  these are frequently tested in technical rounds.                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research TCS Digital placement preparation for B.Tech students. Include hiring process, technical        │
# │  stack, eligibility, recent hiring trends, and preparation tips. Give 3-5 bullets per section.                  │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  ID: 1e880162-2b68-4400-bc35-feedfb43b709                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Task: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  # TCS Digital — Placement Prep Brief                                                                           │
# │                                                                                                                 │
# │  Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers a premium pathway for top      │
# │  B.Tech talent seeking specialized roles and a competitive edge. This brief will guide you through the          │
# │  essentials to secure your spot among the brightest minds.                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 1. The Hiring Process                                                                                      │
# │                                                                                                                 │
# │  TCS Digital's selection is rigorous, designed to identify top technical aptitude and problem-solving skills.   │
# │  Be ready for:                                                                                                  │
# │                                                                                                                 │
# │  *   **Online Assessment:** Advanced quantitative aptitude, verbal ability, and 2-3 complex coding questions    │
# │  (heavy on Data Structures & Algorithms).                                                                       │
# │  *   **Technical Interview:** Deep dive into DSA, core CS subjects (OS, DBMS, OOPs, CN), detailed discussions   │
# │  on your projects, and scenario-based problem-solving.                                                          │
# │  *   **Managerial Interview (Optional):** Evaluates project management, leadership potential, and ability to    │
# │  tackle real-world challenges.                                                                                  │
# │  *   **HR Interview:** Assesses communication skills, cultural fit, career aspirations, and basic HR            │
# │  compliance.                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 2. Essential Technical Stack                                                                               │
# │                                                                                                                 │
# │  Your technical prowess is key. Focus on mastering:                                                             │
# │                                                                                                                 │
# │  *   **Programming Languages:** Strong proficiency in at least one modern language (Java, Python, C++, C#).     │
# │  *   **Data Structures & Algorithms (DSA):** In-depth knowledge and practical application of advanced DSA       │
# │  concepts are absolutely crucial.                                                                               │
# │  *   **Core CS Fundamentals:** Solid grasp of Operating Systems, Database Management Systems, Object-Oriented   │
# │  Programming (OOPs), and Computer Networks.                                                                     │
# │  *   **Web Technologies:** Understanding HTML, CSS, JavaScript; familiarity with frameworks (React, Angular,    │
# │  Node.js) is a plus for relevant roles.                                                                         │
# │  *   **Databases & Cloud:** Basic knowledge of SQL/NoSQL databases and familiarity with cloud platforms (AWS,   │
# │  Azure, GCP) can provide an advantage.                                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 3. Eligibility Criteria                                                                                    │
# │                                                                                                                 │
# │  Ensure you meet the basic academic requirements:                                                               │
# │                                                                                                                 │
# │  *   **Academic Qualification:** B.E./B.Tech/M.E./M.Tech/MCA/M.Sc in relevant streams (CS, IT, ECE, EEE,        │
# │  etc.).                                                                                                         │
# │  *   **Academic Percentage:** Generally, a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and Graduation     │
# │  (or Post-Graduation).                                                                                          │
# │  *   **Backlogs:** Usually no active backlogs allowed at the time of application or joining.                    │
# │  *   **Gap in Education:** A maximum permissible gap of 1-2 years in your academic career is often specified.   │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 4. Recent Hiring Trends                                                                                    │
# │                                                                                                                 │
# │  Stay updated with what TCS Digital is looking for:                                                             │
# │                                                                                                                 │
# │  *   **Niche Skills Focus:** Increased demand for candidates skilled in AI/ML, Data Science, Cloud Computing,   │
# │  Cybersecurity, and IoT.                                                                                        │
# │  *   **Advanced Problem-Solving:** Higher emphasis on practical application of coding and advanced              │
# │  problem-solving over mere theoretical knowledge.                                                               │
# │  *   **Specialized Roles:** Hiring targets specific roles like Full Stack Developer, Data Engineer, Cloud       │
# │  Engineer, AI/ML Engineer, rather than generalist profiles.                                                     │
# │  *   **Higher Compensation:** TCS Digital offers significantly higher compensation packages compared to TCS     │
# │  Ninja, attracting top-tier talent.                                                                             │
# │  *   **Virtual Recruitment:** The entire hiring process, including assessments and interviews, is               │
# │  predominantly conducted online.                                                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 5. Effective Preparation Tips                                                                              │
# │                                                                                                                 │
# │  Strategize your preparation for success:                                                                       │
# │                                                                                                                 │
# │  *   **Master DSA:** Dedicate significant time to practicing Data Structures and Algorithms; solve              │
# │  medium-to-hard problems on platforms like LeetCode, HackerRank, and GeeksforGeeks.                             │
# │  *   **Choose a Core Language:** Become highly proficient in one programming language (Java/Python/C++) and     │
# │  understand its advanced features and libraries.                                                                │
# │  *   **Build Projects:** Develop personal projects that demonstrate your skills in relevant technologies or     │
# │  use advanced DSA concepts; be ready to explain them thoroughly.                                                │
# │  *   **Practice Mock Interviews:** Participate in mock technical interviews to improve your problem-solving     │
# │  under pressure and articulate your thought process clearly.                                                    │
# │  *   **Strengthen CS Fundamentals:** Revise core computer science subjects (OS, DBMS, OOPs, CN) thoroughly, as  │
# │  these are frequently tested in technical rounds.                                                               │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  The competition for TCS Digital is intense, but the rewards are significant.                                   │
# │  Start your preparation early, stay persistent, and showcase your best self.                                    │
# │  Your digital future awaits – prepare to seize it!                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Using the research notes, produce a 1-page placement brief for B.Tech students. Use markdown format.     │
# │  Include a 3-line opening hook, 5 clear sections, and a 3-line closing call-to-action.                          │
# │  Agent: Placement Brief Writer                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# === FINAL OUTPUT ===
#
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers a premium pathway for top B.Tech talent seeking specialized roles and a competitive edge. This brief will guide you through the essentials to secure your spot among the brightest minds.
#
# ---
#
# ### 1. The Hiring Process
#
# TCS Digital's selection is rigorous, designed to identify top technical aptitude and problem-solving skills. Be ready for:
#
# *   **Online Assessment:** Advanced quantitative aptitude, verbal ability, and 2-3 complex coding questions (heavy on Data Structures & Algorithms).
# *   **Technical Interview:** Deep dive into DSA, core CS subjects (OS, DBMS, OOPs, CN), detailed discussions on your projects, and scenario-based problem-solving.
# *   **Managerial Interview (Optional):** Evaluates project management, leadership potential, and ability to tackle real-world challenges.
# *   **HR Interview:** Assesses communication skills, cultural fit, career aspirations, and basic HR compliance.
#
# ---
#
# ### 2. Essential Technical Stack
#
# Your technical prowess is key. Focus on mastering:
#
# *   **Programming Languages:** Strong proficiency in at least one modern language (Java, Python, C++, C#).
# *   **Data Structures & Algorithms (DSA):** In-depth knowledge and practical application of advanced DSA concepts are absolutely crucial.
# *   **Core CS Fundamentals:** Solid grasp of Operating Systems, Database Management Systems, Object-Oriented Programming (OOPs), and Computer Networks.
# *   **Web Technologies:** Understanding HTML, CSS, JavaScript; familiarity with frameworks (React, Angular, Node.js) is a plus for relevant roles.
# *   **Databases & Cloud:** Basic knowledge of SQL/NoSQL databases and familiarity with cloud platforms (AWS, Azure, GCP) can provide an advantage.
#
# ---
#
# ### 3. Eligibility Criteria
#
# Ensure you meet the basic academic requirements:
#
# *   **Academic Qualification:** B.E./B.Tech/M.E./M.Tech/MCA/M.Sc in relevant streams (CS, IT, ECE, EEE, etc.).
# *   **Academic Percentage:** Generally, a minimum of 60% or 6.0 CGPA throughout 10th, 12th, and Graduation (or Post-Graduation).
# *   **Backlogs:** Usually no active backlogs allowed at the time of application or joining.
# *   **Gap in Education:** A maximum permissible gap of 1-2 years in your academic career is often specified.
#
# ---
#
# ### 4. Recent Hiring Trends
#
# Stay updated with what TCS Digital is looking for:
#
# *   **Niche Skills Focus:** Increased demand for candidates skilled in AI/ML, Data Science, Cloud Computing, Cybersecurity, and IoT.
# *   **Advanced Problem-Solving:** Higher emphasis on practical application of coding and advanced problem-solving over mere theoretical knowledge.
# *   **Specialized Roles:** Hiring targets specific roles like Full Stack Developer, Data Engineer, Cloud Engineer, AI/ML Engineer, rather than generalist profiles.
# *   **Higher Compensation:** TCS Digital offers significantly higher compensation packages compared to TCS Ninja, attracting top-tier talent.
# *   **Virtual Recruitment:** The entire hiring process, including assessments and interviews, is predominantly conducted online.
#
# ---
#
# ### 5. Effective Preparation Tips
#
# Strategize your preparation for success:
#
# *   **Master DSA:** Dedicate significant time to practicing Data Structures and Algorithms; solve medium-to-hard problems on platforms like LeetCode, HackerRank, and GeeksforGeeks.
# *   **Choose a Core Language:** Become highly proficient in one programming language (Java/Python/C++) and understand its advanced features and libraries.
# *   **Build Projects:** Develop personal projects that demonstrate your skills in relevant technologies or use advanced DSA concepts; be ready to explain them thoroughly.
# *   **Practice Mock Interviews:** Participate in mock technical interviews to improve your problem-solving under pressure and articulate your thought process clearly.
# *   **Strengthen CS Fundamentals:** Revise core computer science subjects (OS, DBMS, OOPs, CN) thoroughly, as these are frequently tested in technical rounds.
#
# ---
#
# The competition for TCS Digital is intense, but the rewards are significant.
# Start your preparation early, stay persistent, and showcase your best self.
# Your digital future awaits – prepare to seize it!
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
import pathlib

pathlib.Path("day10_lab10a_transcript.txt").write_text(str(result))

print("Saved: day10_lab10a_transcript.txt")
print("Characters:", len(str(result)))
# Out:
# Saved: day10_lab10a_transcript.txt
# Characters: 4258

# %%
try:
    for i, output in enumerate(result.tasks_output):
        print(f"\n=== Task {i+1} Output ===")
        print(str(output)[:800])
except Exception:
    print("Task outputs not available in this CrewAI version.")
    print("Final result saved successfully.")
# Out:
# === Task 1 Output ===
# Here's a placement brief for TCS Digital preparation for B.Tech students:
#
# ### Hiring Process
# *   **Online Assessment:** Typically consists of advanced quantitative aptitude, verbal ability, and two-to-three advanced coding questions (often involving DSA concepts).
# *   **Technical Interview:** Focuses on in-depth DSA, core computer science subjects (OS, DBMS, OOPS, CN), project discussions, and problem-solving scenarios.
# *   **Managerial Interview (Optional):** May assess project management skills, leadership potential, and ability to handle real-world challenges.
# *   **HR Interview:** Evaluates communication skills, cultural fit, career aspirations, and basic HR compliance checks.
#
# ### Technical Stack
# *   **Programming Languages:** Strong proficiency in at least one modern language like J
#
# === Task 2 Output ===
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers a premium pathway for top B.Tech talent seeking specialized roles and a competitive edge. This brief will guide you through the essentials to secure your spot among the brightest minds.
#
# ---
#
# ### 1. The Hiring Process
#
# TCS Digital's selection is rigorous, designed to identify top technical aptitude and problem-solving skills. Be ready for:
#
# *   **Online Assessment:** Advanced quantitative aptitude, verbal ability, and 2-3 complex coding questions (heavy on Data Structures & Algorithms).
# *   **Technical Interview:** Deep dive into DSA, core CS subjects (OS, DBMS, OOPs, CN), detailed discussions on your projects, and scenario-based problem-solving.
# *   **Managerial Interview

# %%
markdown_content = str(result)

with open("tcs_digital_brief.md", "w", encoding="utf-8") as f:
    f.write(markdown_content)

print("Markdown file created successfully: tcs_digital_brief.md")
# Out:
# Markdown file created successfully: tcs_digital_brief.md

# %%
from google.colab import files

files.download("tcs_digital_brief.md")

# %%
with open("tcs_digital_brief.md", "r", encoding="utf-8") as f:
    print(f.read()[:2000])
# Out:
# # TCS Digital — Placement Prep Brief
#
# Dreaming of a high-impact career in cutting-edge technology? TCS Digital offers a premium pathway for top B.Tech talent seeking specialized roles and a competitive edge. This brief will guide you through the essentials to secure your spot among the brightest minds.
#
# ---
#
# ### 1. The Hiring Process
#
# TCS Digital's selection is rigorous, designed to identify top technical aptitude and problem-solving skills. Be ready for:
#
# *   **Online Assessment:** Advanced quantitative aptitude, verbal ability, and 2-3 complex coding questions (heavy on Data Structures & Algorithms).
# *   **Technical Interview:** Deep dive into DSA, core CS subjects (OS, DBMS, OOPs, CN), detailed discussions on your projects, and scenario-based problem-solving.
# *   **Managerial Interview (Optional):** Evaluates project management, leadership potential, and ability to tackle real-world challenges.
# *   **HR Interview:** Assesses communication skills, cultural fit, career aspirations, and basic HR compliance.
#
# ---
#
# ### 2. Essential Technical Stack
#
# Your technical prowess is key. Focus on mastering:
#
# *   **Programming Languages:** Strong proficiency in at least one modern language (Java, Python, C++, C#).
# *   **Data Structures & Algorithms (DSA):** In-depth knowledge and practical application of advanced DSA concepts are absolutely crucial.
# *   **Core CS Fundamentals:** Solid grasp of Operating Systems, Database Management Systems, Object-Oriented Programming (OOPs), and Computer Networks.
# *   **Web Technologies:** Understanding HTML, CSS, JavaScript; familiarity with frameworks (React, Angular, Node.js) is a plus for relevant roles.
# *   **Databases & Cloud:** Basic knowledge of SQL/NoSQL databases and familiarity with cloud platforms (AWS, Azure, GCP) can provide an advantage.
#
# ---
#
# ### 3. Eligibility Criteria
#
# Ensure you meet the basic academic requirements:
#
# *   **Academic Qualification:** B.E./B.Tech/M.E./M.Tech/MCA/M.Sc in relevant streams (CS, IT, ECE, EEE, etc.)

# %%
import json
import pathlib

# %%
# The installation commands have been consolidated and moved to the first cell (ECkgHkFAJ6lA) to prevent conflicts and ensure consistent package versions.

# %%
import os, getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter Gemini API Key: ")

print("API key set")
# Out:
# Enter Gemini API Key: ··········
# API key set

# %%
from crewai import Agent, Task, Crew, Process
from crewai.tools import tool as crewai_tool

from chromadb import PersistentClient
from sentence_transformers import SentenceTransformer

import json
import pathlib
# Out:
# 06:02:51 - LiteLLM:WARNING: common_utils.py:979 - litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load bedrock-runtime response stream shape — Bedrock event-stream decoding will be unavailable. Error: No module named 'botocore'
# 06:02:51 - LiteLLM:WARNING: common_utils.py:24 - litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'
# WARNING:LiteLLM:litellm: could not pre-load sagemaker-runtime response stream shape — SageMaker event-stream decoding will be unavailable. Error: No module named 'botocore'

# %%
# !pip uninstall -y numpy
# !pip install numpy==1.26.4
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.3 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# bigframes 2.40.0 requires rich<14,>=12.4.4, but you have rich 14.3.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tifffile 2026.4.11 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4

# %%
llm = "gemini/gemini-2.5-flash"

# %%
client_db = PersistentClient(path='./chroma_db')

col = client_db.get_or_create_collection('placement_kb')

embed = SentenceTransformer(
    'sentence-transformers/all-MiniLM-L6-v2'
)

@crewai_tool
def rag_search(query: str) -> str:
    """
    Search placement knowledge base.
    """

    qv = embed.encode([query]).tolist()

    results = col.query(
        query_embeddings=qv,
        n_results=4
    )

    docs = results['documents'][0]

    return '\n---\n'.join(docs)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
researcher = Agent(
    role="Placement Researcher",

    goal="Research company placement requirements for students",

    backstory="You prepare factual placement research notes using RAG search.",

    llm=llm,

    tools=[rag_search],

    verbose=True,

    allow_delegation=False,
)

# %%
interviewer = Agent(
    role="Mock Interviewer",

    goal="Generate placement interview questions",

    backstory="You generate technical and HR interview questions.",

    llm=llm,

    verbose=True,

    allow_delegation=False,
)
# Out:
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-6' coro=<BaseApiClient.aclose() done, defined at /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py:2174> exception=AttributeError("'BaseApiClient' object has no attribute '_async_httpx_client'")>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py", line 2179, in aclose
#     await self._async_httpx_client.aclose()  # type: ignore[union-attr]
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'BaseApiClient' object has no attribute '_async_httpx_client'

# %%
coach = Agent(
    role="Answer Coach",

    goal="Create strong sample answers and preparation guidance",

    backstory="You coach students with strong placement answers.",

    llm=llm,

    verbose=True,

    allow_delegation=False,
)

# %%
tracker = Agent(
    role="Progress Tracker",

    goal="Create structured student progress summaries",

    backstory="You generate JSON-style student progress summaries.",

    llm=llm,

    verbose=True,

    allow_delegation=False,
)

# %%
profiles = [
    {
        "student_id": "S001",
        "name": "Ravi Kumar",
        "branch": "CSE",
        "cgpa": 7.8,
        "skills": ["Python", "Java", "SQL"],
        "target_company": "TCS Digital"
    },

    {
        "student_id": "S002",
        "name": "Sneha Reddy",
        "branch": "ECE",
        "cgpa": 8.1,
        "skills": ["Python", "DBMS"],
        "target_company": "Cognizant"
    },

    {
        "student_id": "S003",
        "name": "Arun Pillai",
        "branch": "IT",
        "cgpa": 8.5,
        "skills": ["Java", "DSA", "OOPs"],
        "target_company": "Amazon"
    }
]

# %%
def build_tasks(profile):

    research = Task(
        description=(
            f"Research placement preparation details for "
            f"{profile['target_company']} "
            f"for a {profile['branch']} student."
        ),

        agent=researcher,

        expected_output="Short bullet research notes."
    )

    interview = Task(
        description=(
            f"Generate EXACTLY 10 mock interview questions "
            f"for {profile['name']} targeting "
            f"{profile['target_company']}."
        ),

        agent=interviewer,

        expected_output="Exactly 10 numbered interview questions."
    )

    coaching = Task(
        description=(
            f"Pick question 3 and create strong sample answer "
            f"for {profile['name']}."
        ),

        agent=coach,

        expected_output="One strong answer and 3 preparation tips."
    )

    tracking = Task(
        description=(
            f"Create JSON-style progress summary "
            f"for {profile['student_id']}."
        ),

        agent=tracker,

        expected_output="Valid JSON-style summary."
    )

    return [research, interview, coaching, tracking]

# %%
p = profiles[0]

crew = Crew(
    agents=[
        researcher,
        interviewer,
        coach,
        tracker
    ],

    tasks=build_tasks(p),

    process=Process.sequential,

    verbose=True,
)

# %%
result = await crew.kickoff_async()

print("\n=== FINAL OUTPUT ===\n")

print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: fb356b89-b387-448c-969b-fbd5d25b273a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  ID: 301b9574-5026-4818-af35-a1390bbbed01                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for TCS Digital for a CSE student.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │  Args: {'query': 'TCS Digital placement preparation details for CSE student'}                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool rag_search executed with result: ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#2) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │  Args: {'query': 'TCS Digital placement preparation'}                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool rag_search executed with result: ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#2) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: rag_search                                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  I am sorry, but I could not find any information regarding TCS Digital placement preparation details for a     │
# │  CSE student in my knowledge base.                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Generate EXACTLY 10 mock interview questions for Ravi Kumar targeting TCS Digital.                       │
# │  ID: de24513a-f47a-4ad8-a85b-73ec95fa355e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Mock Interviewer                                                                                        │
# │                                                                                                                 │
# │  Task: Generate EXACTLY 10 mock interview questions for Ravi Kumar targeting TCS Digital.                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Mock Interviewer                                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 10 mock interview questions for Ravi Kumar targeting TCS Digital:                                     │
# │                                                                                                                 │
# │  1.  Ravi, please introduce yourself and tell us a bit about your academic background, key projects, and what   │
# │  motivates you in the field of computer science.                                                                │
# │  2.  Can you explain the difference between a `HashMap` and a `ConcurrentHashMap` in Java (or an equivalent     │
# │  data structure in Python/C++ if you prefer) and in what scenarios you would use each?                          │
# │  3.  Describe a challenging technical problem you've encountered in a project or during your studies. How did   │
# │  you approach solving it, and what did you learn from the experience?                                           │
# │  4.  What are the ACID properties in the context of database transactions? Provide a real-world example of how  │
# │  violating one of these properties could lead to issues.                                                        │
# │  5.  TCS Digital focuses on modern solutions. Are you familiar with any cloud computing platforms (like AWS,    │
# │  Azure, or GCP)? If so, describe a service you've explored and how it could be used in an application.          │
# │  6.  Imagine you need to design a system to recommend products to users based on their browsing history. What   │
# │  data structures and algorithms would you consider, and what challenges might you face?                         │
# │  7.  What is polymorphism in Object-Oriented Programming? Provide an example in code (you don't need to write   │
# │  full code, just explain the concept with a scenario).                                                          │
# │  8.  Describe a time when you had to work effectively in a team to achieve a common goal. What was your role,   │
# │  and how did you handle any disagreements or conflicts?                                                         │
# │  9.  Why are you specifically interested in the TCS Digital profile, and how do you see your skills and         │
# │  aspirations aligning with the opportunities this role offers?                                                  │
# │  10. The technology landscape is constantly evolving. How do you ensure you stay updated with new               │
# │  technologies, programming languages, and industry best practices?                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Generate EXACTLY 10 mock interview questions for Ravi Kumar targeting TCS Digital.                       │
# │  Agent: Mock Interviewer                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Pick question 3 and create strong sample answer for Ravi Kumar.                                          │
# │  ID: 27518459-5f83-4099-bef4-4530eeb02d04                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Answer Coach                                                                                            │
# │                                                                                                                 │
# │  Task: Pick question 3 and create strong sample answer for Ravi Kumar.                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Answer Coach                                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here's a strong sample answer for Ravi Kumar for question 3, along with preparation tips:                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### Strong Sample Answer for Ravi Kumar (Question 3)                                                           │
# │                                                                                                                 │
# │  **Question:** Describe a challenging technical problem you've encountered in a project or during your          │
# │  studies. How did you approach solving it, and what did you learn from the experience?                          │
# │                                                                                                                 │
# │  **Ravi Kumar's Answer:**                                                                                       │
# │                                                                                                                 │
# │  "Certainly. During my final year project, 'MediConnect,' a web-based platform for doctor appointment booking   │
# │  and patient record management, we encountered a significant performance bottleneck that proved quite           │
# │  challenging.                                                                                                   │
# │                                                                                                                 │
# │  **The Problem:** The core issue was with the patient dashboard, which aggregated and displayed various data    │
# │  points like upcoming appointments, past visit summaries, and diagnostic reports. When multiple users tried to  │
# │  access their dashboards concurrently, or when a patient had a long history, the page load times escalated      │
# │  dramatically, sometimes taking over 10-15 seconds. This was unacceptable for a real-time application.          │
# │                                                                                                                 │
# │  **My Approach:**                                                                                               │
# │  1.  **Initial Diagnostics:** As the backend developer, my first step was to pinpoint the exact source of the   │
# │  delay. I integrated Spring Boot Actuator's `/metrics` and used basic profiling with `System.nanoTime()` in     │
# │  critical service methods. This quickly revealed that the overwhelming majority of time was spent executing     │
# │  database queries, specifically when fetching aggregated patient data.                                          │
# │  2.  **Deep Dive into Queries:** We were using MySQL, and I enabled SQL logging in Hibernate to capture the     │
# │  actual queries being executed. I then leveraged MySQL's `EXPLAIN` command for the slowest queries. This        │
# │  analysis showed that many complex `JOIN` operations across large tables (e.g., `patients`, `appointments`,     │
# │  `medical_records`, `doctors`) were leading to full table scans and inefficient temporary table usage, even     │
# │  for relatively simple data retrieval.                                                                          │
# │  3.  **Optimization Strategy:**                                                                                 │
# │      *   **Intelligent Indexing:** I identified frequently filtered and joined columns (such as `patient_id`,   │
# │  `doctor_id`, `appointment_date`, `status`, `record_type`) and implemented appropriate B-tree indexes. This     │
# │  significantly optimized lookup times.                                                                          │
# │      *   **Query Refactoring:** I re-evaluated and rewrote several problematic queries. Instead of fetching     │
# │  all related data with a massive multi-table join, I broke them down. For instance, for specific aggregated     │
# │  counts, I would fetch a small set of primary keys first and then use `IN` clauses or separate, targeted        │
# │  queries to retrieve specific details, drastically reducing the dataset processed at each step.                 │
# │      *   **Selective Data Fetching:** For lists and tables, I implemented pagination and 'limit-offset'         │
# │  clauses to ensure we only loaded the necessary subset of data for the current view, rather than retrieving     │
# │  everything from the database.                                                                                  │
# │      *   **Caching (Consideration):** While not fully implemented for this specific bottleneck, we also         │
# │  discussed and planned for a caching layer (e.g., Redis) for highly static or frequently accessed aggregated    │
# │  data, which would have been the next step if direct database optimizations weren't sufficient.                 │
# │                                                                                                                 │
# │  **The Outcome and Lessons Learned:**                                                                           │
# │  After implementing these changes, the patient dashboard loading time improved dramatically, coming down from   │
# │  10-15 seconds to a consistent 1.5-2 seconds, even under load.                                                  │
# │                                                                                                                 │
# │  This experience was a profound learning curve for me.                                                          │
# │  *   **Technical Learnings:** I gained a much deeper practical understanding of database indexing, the nuances  │
# │  of query execution plans, and the performance implications of different SQL constructs. It also highlighted    │
# │  the critical role of profiling tools in identifying performance bottlenecks.                                   │
# │  *   **Problem-Solving Skills:** Beyond the technical aspect, it reinforced the importance of a systematic and  │
# │  iterative approach to problem-solving. Starting with broad identification, then drilling down with specific    │
# │  diagnostic tools, and finally implementing and testing solutions while continuously measuring their impact.    │
# │  It taught me that performance should be a design consideration, not just an afterthought, and that often, the  │
# │  root cause is not where you initially expect it to be."                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### 3 Preparation Tips for This Question                                                                       │
# │                                                                                                                 │
# │  1.  **Choose a Truly Technical and Specific Problem:** Don't pick a simple bug fix or a general project        │
# │  management challenge. Select a problem that required you to delve deep into technical concepts (e.g.,          │
# │  algorithm optimization, database performance, complex API integration, concurrency issues, data structure      │
# │  choice). Be ready to explain the technical details, the tools you used, and the specific decisions you made.   │
# │                                                                                                                 │
# │  2.  **Structure Your Answer with STAR (Situation, Task, Action, Result):** This framework helps you tell a     │
# │  clear, concise, and compelling story.                                                                          │
# │      *   **S (Situation):** Briefly set the context (project, your role, initial state).                        │
# │      *   **T (Task):** Clearly state the problem you needed to solve.                                           │
# │      *   **A (Action):** Detail the steps *you* took to solve it. This is your chance to showcase your          │
# │  problem-solving process, research, debugging, and specific technical implementations. Use accurate technical   │
# │  terms.                                                                                                         │
# │      *   **R (Result & Learning):** Explain the positive outcome and, critically, what *you* learned from the   │
# │  experience – both technically and about your problem-solving approach or personal growth.                      │
# │                                                                                                                 │
# │  3.  **Focus on Your Contributions and Learnings:** The interviewer wants to understand *your* thought process  │
# │  and *your* growth. Even if it was a team project, emphasize *your* specific role and actions ("I               │
# │  investigated," "I implemented," "My analysis showed"). The "lessons learned" section is crucial; it            │
# │  demonstrates self-awareness, adaptability, and a continuous learning mindset, which are highly valued in       │
# │  roles like TCS Digital. Rehearse articulating not just *what* you did, but *why* you chose that approach and   │
# │  what broader insights you gained.                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Pick question 3 and create strong sample answer for Ravi Kumar.                                          │
# │  Agent: Answer Coach                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Create JSON-style progress summary for S001.                                                             │
# │  ID: 697916e5-8292-4a84-bff1-c82748a4896e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Progress Tracker                                                                                        │
# │                                                                                                                 │
# │  Task: Create JSON-style progress summary for S001.                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Progress Tracker                                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ```json                                                                                                        │
# │  {                                                                                                              │
# │    "student_id": "S001",                                                                                        │
# │    "progress_summary": {                                                                                        │
# │      "overall_preparation_status": "Initial stage, mock interview questions and sample answer provided for      │
# │  review.",                                                                                                      │
# │      "tcs_digital_prep_context": "No specific TCS Digital placement preparation details found in the knowledge  │
# │  base, focusing on general technical and behavioral skills relevant for TCS Digital profile.",                  │
# │      "mock_interview_focus": "10 questions provided covering technical (Java, Data Structures, Databases,       │
# │  Cloud, OOP, System Design) and behavioral aspects, specifically tailored for TCS Digital.",                    │
# │      "mock_interview_questions": [                                                                              │
# │        "Ravi, please introduce yourself and tell us a bit about your academic background, key projects, and     │
# │  what motivates you in the field of computer science.",                                                         │
# │        "Can you explain the difference between a `HashMap` and a `ConcurrentHashMap` in Java (or an equivalent  │
# │  data structure in Python/C++ if you prefer) and in what scenarios you would use each?",                        │
# │        "Describe a challenging technical problem you've encountered in a project or during your studies. How    │
# │  did you approach solving it, and what did you learn from the experience?",                                     │
# │        "What are the ACID properties in the context of database transactions? Provide a real-world example of   │
# │  how violating one of these properties could lead to issues.",                                                  │
# │        "TCS Digital focuses on modern solutions. Are you familiar with any cloud computing platforms (like      │
# │  AWS, Azure, or GCP)? If so, describe a service you've explored and how it could be used in an application.",   │
# │        "Imagine you need to design a system to recommend products to users based on their browsing history.     │
# │  What data structures and algorithms would you consider, and what challenges might you face?",                  │
# │        "What is polymorphism in Object-Oriented Programming? Provide an example in code (you don't need to      │
# │  write full code, just explain the concept with a scenario).",                                                  │
# │        "Describe a time when you had to work effectively in a team to achieve a common goal. What was your      │
# │  role, and how did you handle any disagreements or conflicts?",                                                 │
# │        "Why are you specifically interested in the TCS Digital profile, and how do you see your skills and      │
# │  aspirations aligning with the opportunities this role offers?",                                                │
# │        "The technology landscape is constantly evolving. How do you ensure you stay updated with new            │
# │  technologies, programming languages, and industry best practices?"                                             │
# │      ],                                                                                                         │
# │      "detailed_feedback_q3": {                                                                                  │
# │        "question": "Describe a challenging technical problem you've encountered in a project or during your     │
# │  studies. How did you approach solving it, and what did you learn from the experience?",                        │
# │        "sample_answer_summary": {                                                                               │
# │          "student_name": "Ravi Kumar",                                                                          │
# │          "problem_identified": "Significant performance bottleneck in 'MediConnect' patient dashboard due to    │
# │  slow page load times (10-15 seconds) when multiple users accessed or with long patient history.",              │
# │          "root_cause": "Overwhelming time spent on database queries (MySQL) executing complex JOINs across      │
# │  large tables, leading to full table scans and inefficient temporary table usage.",                             │
# │          "approach_taken": [                                                                                    │
# │            "**Initial Diagnostics:** Used Spring Boot Actuator's `/metrics` and `System.nanoTime()` for         │
# │  profiling, confirming database queries as the bottleneck.",                                                    │
# │            "**Deep Dive:** Enabled SQL logging (Hibernate) and used MySQL's `EXPLAIN` command to analyze slow   │
# │  queries, identifying inefficient JOINs.",                                                                      │
# │            "**Optimization Strategy:** Implemented intelligent B-tree indexing on frequently filtered/joined    │
# │  columns, refactored queries to break down complex JOINs into targeted queries with `IN` clauses, and           │
# │  implemented pagination/limit-offset for selective data fetching.",                                             │
# │            "**Considered:** Caching layer (Redis) for future improvements."                                     │
# │          ],                                                                                                     │
# │          "outcome": "Dashboard loading time improved dramatically from 10-15 seconds to a consistent 1.5-2      │
# │  seconds, even under load.",                                                                                    │
# │          "lessons_learned": [                                                                                   │
# │            "**Technical:** Gained deeper understanding of database indexing, query execution plans,             │
# │  performance implications of SQL constructs, and role of profiling tools.",                                     │
# │            "**Problem-Solving:** Reinforced systematic and iterative approach, importance of performance as a   │
# │  design consideration, and that root cause might not be obvious."                                               │
# │          ]                                                                                                      │
# │        },                                                                                                       │
# │        "preparation_tips_q3": [                                                                                 │
# │          "**Choose a Truly Technical and Specific Problem:** Select a problem that required deep technical      │
# │  engagement (e.g., algorithm optimization, database performance, concurrency) and be ready to detail technical  │
# │  aspects and tools used.",                                                                                      │
# │          "**Structure Your Answer with STAR (Situation, Task, Action, Result):** Clearly set the context,       │
# │  state the problem, detail *your* specific actions and technical implementations, and explain the positive      │
# │  outcome and *your* learnings.",                                                                                │
# │          "**Focus on Your Contributions and Learnings:** Emphasize *your* role and actions ('I investigated,'   │
# │  'I implemented') and articulate the technical and personal insights gained, demonstrating self-awareness and   │
# │  a continuous learning mindset."                                                                                │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    }                                                                                                            │
# │  }                                                                                                              │
# │  ```                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Create JSON-style progress summary for S001.                                                             │
# │  Agent: Progress Tracker                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# === FINAL OUTPUT ===
#
# ```json
# {
#   "student_id": "S001",
#   "progress_summary": {
#     "overall_preparation_status": "Initial stage, mock interview questions and sample answer provided for review.",
#     "tcs_digital_prep_context": "No specific TCS Digital placement preparation details found in the knowledge base, focusing on general technical and behavioral skills relevant for TCS Digital profile.",
#     "mock_interview_focus": "10 questions provided covering technical (Java, Data Structures, Databases, Cloud, OOP, System Design) and behavioral aspects, specifically tailored for TCS Digital.",
#     "mock_interview_questions": [
#       "Ravi, please introduce yourself and tell us a bit about your academic background, key projects, and what motivates you in the field of computer science.",
#       "Can you explain the difference between a `HashMap` and a `ConcurrentHashMap` in Java (or an equivalent data structure in Python/C++ if you prefer) and in what scenarios you would use each?",
#       "Describe a challenging technical problem you've encountered in a project or during your studies. How did you approach solving it, and what did you learn from the experience?",
#       "What are the ACID properties in the context of database transactions? Provide a real-world example of how violating one of these properties could lead to issues.",
#       "TCS Digital focuses on modern solutions. Are you familiar with any cloud computing platforms (like AWS, Azure, or GCP)? If so, describe a service you've explored and how it could be used in an application.",
#       "Imagine you need to design a system to recommend products to users based on their browsing history. What data structures and algorithms would you consider, and what challenges might you face?",
#       "What is polymorphism in Object-Oriented Programming? Provide an example in code (you don't need to write full code, just explain the concept with a scenario).",
#       "Describe a time when you had to work effectively in a team to achieve a common goal. What was your role, and how did you handle any disagreements or conflicts?",
#       "Why are you specifically interested in the TCS Digital profile, and how do you see your skills and aspirations aligning with the opportunities this role offers?",
#       "The technology landscape is constantly evolving. How do you ensure you stay updated with new technologies, programming languages, and industry best practices?"
#     ],
#     "detailed_feedback_q3": {
#       "question": "Describe a challenging technical problem you've encountered in a project or during your studies. How did you approach solving it, and what did you learn from the experience?",
#       "sample_answer_summary": {
#         "student_name": "Ravi Kumar",
#         "problem_identified": "Significant performance bottleneck in 'MediConnect' patient dashboard due to slow page load times (10-15 seconds) when multiple users accessed or with long patient history.",
#         "root_cause": "Overwhelming time spent on database queries (MySQL) executing complex JOINs across large tables, leading to full table scans and inefficient temporary table usage.",
#         "approach_taken": [
#           "**Initial Diagnostics:** Used Spring Boot Actuator's `/metrics` and `System.nanoTime()` for profiling, confirming database queries as the bottleneck.",
#           "**Deep Dive:** Enabled SQL logging (Hibernate) and used MySQL's `EXPLAIN` command to analyze slow queries, identifying inefficient JOINs.",
#           "**Optimization Strategy:** Implemented intelligent B-tree indexing on frequently filtered/joined columns, refactored queries to break down complex JOINs into targeted queries with `IN` clauses, and implemented pagination/limit-offset for selective data fetching.",
#           "**Considered:** Caching layer (Redis) for future improvements."
#         ],
#         "outcome": "Dashboard loading time improved dramatically from 10-15 seconds to a consistent 1.5-2 seconds, even under load.",
#         "lessons_learned": [
#           "**Technical:** Gained deeper understanding of database indexing, query execution plans, performance implications of SQL constructs, and role of profiling tools.",
#           "**Problem-Solving:** Reinforced systematic and iterative approach, importance of performance as a design consideration, and that root cause might not be obvious."
#         ]
#       },
#       "preparation_tips_q3": [
#         "**Choose a Truly Technical and Specific Problem:** Select a problem that required deep technical engagement (e.g., algorithm optimization, database performance, concurrency) and be ready to detail technical aspects and tools used.",
#         "**Structure Your Answer with STAR (Situation, Task, Action, Result):** Clearly set the context, state the problem, detail *your* specific actions and technical implementations, and explain the positive outcome and *your* learnings.",
#         "**Focus on Your Contributions and Learnings:** Emphasize *your* role and actions ('I investigated,' 'I implemented') and articulate the technical and personal insights gained, demonstrating self-awareness and a continuous learning mindset."
#       ]
#     }
#   }
# }
# ```
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: fb356b89-b387-448c-969b-fbd5d25b273a                                                                       │
# │  Final Output: ```json                                                                                          │
# │  {                                                                                                              │
# │    "student_id": "S001",                                                                                        │
# │    "progress_summary": {                                                                                        │
# │      "overall_preparation_status": "Initial stage, mock interview questions and sample answer provided for      │
# │  review.",                                                                                                      │
# │      "tcs_digital_prep_context": "No specific TCS Digital placement preparation details found in the knowledge  │
# │  base, focusing on general technical and behavioral skills relevant for TCS Digital profile.",                  │
# │      "mock_interview_focus": "10 questions provided covering technical (Java, Data Structures, Databases,       │
# │  Cloud, OOP, System Design) and behavioral aspects, specifically tailored for TCS Digital.",                    │
# │      "mock_interview_questions": [                                                                              │
# │        "Ravi, please introduce yourself and tell us a bit about your academic background, key projects, and     │
# │  what motivates you in the field of computer science.",                                                         │
# │        "Can you explain the difference between a `HashMap` and a `ConcurrentHashMap` in Java (or an equivalent  │
# │  data structure in Python/C++ if you prefer) and in what scenarios you would use each?",                        │
# │        "Describe a challenging technical problem you've encountered in a project or during your studies. How    │
# │  did you approach solving it, and what did you learn from the experience?",                                     │
# │        "What are the ACID properties in the context of database transactions? Provide a real-world example of   │
# │  how violating one of these properties could lead to issues.",                                                  │
# │        "TCS Digital focuses on modern solutions. Are you familiar with any cloud computing platforms (like      │
# │  AWS, Azure, or GCP)? If so, describe a service you've explored and how it could be used in an application.",   │
# │        "Imagine you need to design a system to recommend products to users based on their browsing history.     │
# │  What data structures and algorithms would you consider, and what challenges might you face?",                  │
# │        "What is polymorphism in Object-Oriented Programming? Provide an example in code (you don't need to      │
# │  write full code, just explain the concept with a scenario).",                                                  │
# │        "Describe a time when you had to work effectively in a team to achieve a common goal. What was your      │
# │  role, and how did you handle any disagreements or conflicts?",                                                 │
# │        "Why are you specifically interested in the TCS Digital profile, and how do you see your skills and      │
# │  aspirations aligning with the opportunities this role offers?",                                                │
# │        "The technology landscape is constantly evolving. How do you ensure you stay updated with new            │
# │  technologies, programming languages, and industry best practices?"                                             │
# │      ],                                                                                                         │
# │      "detailed_feedback_q3": {                                                                                  │
# │        "question": "Describe a challenging technical problem you've encountered in a project or during your     │
# │  studies. How did you approach solving it, and what did you learn from the experience?",                        │
# │        "sample_answer_summary": {                                                                               │
# │          "student_name": "Ravi Kumar",                                                                          │
# │          "problem_identified": "Significant performance bottleneck in 'MediConnect' patient dashboard due to    │
# │  slow page load times (10-15 seconds) when multiple users accessed or with long patient history.",              │
# │          "root_cause": "Overwhelming time spent on database queries (MySQL) executing complex JOINs across      │
# │  large tables, leading to full table scans and inefficient temporary table usage.",                             │
# │          "approach_taken": [                                                                                    │
# │            "**Initial Diagnostics:** Used Spring Boot Actuator's `/metrics` and `System.nanoTime()` for         │
# │  profiling, confirming database queries as the bottleneck.",                                                    │
# │            "**Deep Dive:** Enabled SQL logging (Hibernate) and used MySQL's `EXPLAIN` command to analyze slow   │
# │  queries, identifying inefficient JOINs.",                                                                      │
# │            "**Optimization Strategy:** Implemented intelligent B-tree indexing on frequently filtered/joined    │
# │  columns, refactored queries to break down complex JOINs into targeted queries with `IN` clauses, and           │
# │  implemented pagination/limit-offset for selective data fetching.",                                             │
# │            "**Considered:** Caching layer (Redis) for future improvements."                                     │
# │          ],                                                                                                     │
# │          "outcome": "Dashboard loading time improved dramatically from 10-15 seconds to a consistent 1.5-2      │
# │  seconds, even under load.",                                                                                    │
# │          "lessons_learned": [                                                                                   │
# │            "**Technical:** Gained deeper understanding of database indexing, query execution plans,             │
# │  performance implications of SQL constructs, and role of profiling tools.",                                     │
# │            "**Problem-Solving:** Reinforced systematic and iterative approach, importance of performance as a   │
# │  design consideration, and that root cause might not be obvious."                                               │
# │          ]                                                                                                      │
# │        },                                                                                                       │
# │        "preparation_tips_q3": [                                                                                 │
# │          "**Choose a Truly Technical and Specific Problem:** Select a problem that required deep technical      │
# │  engagement (e.g., algorithm optimization, database performance, concurrency) and be ready to detail technical  │
# │  aspects and tools used.",                                                                                      │
# │          "**Structure Your Answer with STAR (Situation, Task, Action, Result):** Clearly set the context,       │
# │  state the problem, detail *your* specific actions and technical implementations, and explain the positive      │
# │  outcome and *your* learnings.",                                                                                │
# │          "**Focus on Your Contributions and Learnings:** Emphasize *your* role and actions ('I investigated,'   │
# │  'I implemented') and articulate the technical and personal insights gained, demonstrating self-awareness and   │
# │  a continuous learning mindset."                                                                                │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    }                                                                                                            │
# │  }                                                                                                              │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
import os
from getpass import getpass

os.environ["GEMINI_API_KEY"] = getpass("Enter Gemini API Key: ")
# Out:
# Enter Gemini API Key: ··········

# %%
import os

print("GEMINI_API_KEY" in os.environ)
# Out:
# True

# %%
import asyncio
from crewai import Crew, Process

transcripts = []

for p in profiles:

    print("\n" + "="*60)
    print(f"Running for {p['name']} → {p['target_company']}")
    print("="*60)

    crew = Crew(
        agents=[
            researcher,
            interviewer,
            coach,
            tracker
        ],
        tasks=build_tasks(p),
        process=Process.sequential,
        verbose=True,
    )

    max_retries = 5
    success = False

    for attempt in range(max_retries):

        try:

            print(f"\nAttempt {attempt+1}/{max_retries}")

            result = await crew.kickoff_async()

            transcripts.append({
                "student": p["name"],
                "target": p["target_company"],
                "final_output": str(result),
            })

            print(f"✓ Completed for {p['name']}")

            success = True
            break

        except Exception as e:

            print(f"\nError for {p['name']}:")
            print(str(e))

            if attempt < max_retries - 1:
                wait_time = 30

                print(
                    f"Waiting {wait_time} seconds before retry..."
                )

                await asyncio.sleep(wait_time)

            else:

                print(
                    f"✗ Failed after {max_retries} attempts"
                )

    # Small pause between students
    await asyncio.sleep(10)

print("\n" + "="*60)
print("PROCESS FINISHED")
print("="*60)

print(f"Completed transcripts: {len(transcripts)}")

for t in transcripts:

    print("\n" + "-"*60)

    print("Student:", t["student"])

    print("Target:", t["target"])

    print("Output:")
    print(t["final_output"])
# Out:
# ============================================================
# Running for Ravi Kumar → TCS Digital
# ============================================================
#
# Attempt 1/5
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: c622fe93-6c1a-4dc7-8e78-cbcc32c9c3c9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  ID: 916dfd2d-4b3d-488d-8192-763339bf53ff                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for TCS Digital for a CSE student.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 51.263783367s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 51.263783367s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_native_tools: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 51.263783367s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-2.5-flash                                                                                    │
# │  Please retry in 51.263783367s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 51.263783367s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Error for Ravi Kumar:
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 51.263783367s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}
# Waiting 30 seconds before retry...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: c622fe93-6c1a-4dc7-8e78-cbcc32c9c3c9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Attempt 2/5
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: c622fe93-6c1a-4dc7-8e78-cbcc32c9c3c9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  ID: 916dfd2d-4b3d-488d-8192-763339bf53ff                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for TCS Digital for a CSE student.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 20.653093s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 20.653093s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '20s'}]}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_native_tools: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 20.653093s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '20s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-2.5-flash                                                                                    │
# │  Please retry in 20.653093s.                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 20.653093s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '20s'}]}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Error for Ravi Kumar:
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 20.653093s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '20s'}]}}
# Waiting 30 seconds before retry...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: c622fe93-6c1a-4dc7-8e78-cbcc32c9c3c9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Attempt 3/5
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: c622fe93-6c1a-4dc7-8e78-cbcc32c9c3c9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  ID: 916dfd2d-4b3d-488d-8192-763339bf53ff                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for TCS Digital for a CSE student.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 50.120977254s.
# ERROR:crewai.flow.flow:Error executing listener call_llm_native_tools: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 50.120977254s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 50.120977254s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-2.5-flash                                                                                    │
# │  Please retry in 50.120977254s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 50.120977254s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Error for Ravi Kumar:
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 50.120977254s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '50s'}]}}
# Waiting 30 seconds before retry...
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: c622fe93-6c1a-4dc7-8e78-cbcc32c9c3c9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Attempt 4/5
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: c622fe93-6c1a-4dc7-8e78-cbcc32c9c3c9                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  ID: 916dfd2d-4b3d-488d-8192-763339bf53ff                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for TCS Digital for a CSE student.                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 19.577168396s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 19.577168396s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_native_tools: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 19.577168396s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-2.5-flash                                                                                    │
# │  Please retry in 19.577168396s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 19.577168396s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: Research placement preparation details for TCS Digital for a CSE student.                                │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# ...
# Waiting 30 seconds before retry...
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: Research placement preparation details for Amazon for a IT student.                                      │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Attempt 5/5
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: ea2084ee-3f61-45d6-8dec-656c2c657795                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research placement preparation details for Amazon for a IT student.                                      │
# │  ID: 2e8f60c7-ecf4-40b3-96c3-ae007f4484ee                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │  Task: Research placement preparation details for Amazon for a IT student.                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash
# Please retry in 21.658182469s.
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 21.658182469s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '21s'}]}}
# ERROR:crewai.flow.flow:Error executing listener call_llm_native_tools: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 21.658182469s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '21s'}]}}
# ╭───────────────────────────────────────────────── ❌ LLM Error ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  LLM Call Failed                                                                                                │
# │  Error: Google Gemini API error: 429 - You exceeded your current quota, please check your plan and billing      │
# │  details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To    │
# │  monitor your current usage, head to: https://ai.dev/rate-limit.                                                │
# │  * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit:     │
# │  20, model: gemini-2.5-flash                                                                                    │
# │  Please retry in 21.658182469s.                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# An unknown error occurred. Please check the details below.
# Error details: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 21.658182469s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '21s'}]}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Error for Arun Pillai:
# 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 21.658182469s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash', 'location': 'global'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '21s'}]}}
# ✗ Failed after 5 attempts
# ╭──────────────────────────────────────────────── 📋 Task Failure ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Failed                                                                                                    │
# │  Name: Research placement preparation details for Amazon for a IT student.                                      │
# │  Agent: Placement Researcher                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────────── Crew Failure ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Failed                                                                                          │
# │  Name: crew                                                                                                     │
# │  ID: ea2084ee-3f61-45d6-8dec-656c2c657795                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ============================================================
# PROCESS FINISHED
# ============================================================
# Completed transcripts: 0

# %%
md = "# Day10 Sprint5 Report\n\n"

for t in transcripts:

    md += f"## {t['student']} → {t['target']}\n\n"

    md += t["final_output"]

    md += "\n\n---\n\n"

pathlib.Path(
    "day10_sprint5_report.md"
).write_text(md)

print("Markdown report created")
# Out:
# Markdown report created

# %%
from google.colab import files

files.download("/content/day10_lab10a_transcript.txt")

files.download("day10_sprint5_report.md")
