# %% [markdown]
# <a href="https://colab.research.google.com/github/kolaparthisaimeenakshi-crypto/ai-mentor-portfolia/blob/main/day_1setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the complete set of skills required to build, deploy, and manage AI solutions, from foundational data work to cutting-edge research:
#
# *   **Data Engineering (Base):** Focuses on collecting, cleaning, storing, and transforming raw data to make it suitable for AI model training.
# *   **ML Engineering (Next):** Involves developing, training, evaluating, and optimizing machine learning models using prepared data.
# *   **MLOps (Middle):** Deals with deploying, monitoring, maintaining, and scaling AI models in production environments, ensuring reliability and performance.
# *   **AI Product Management (Higher):** Defines the strategy, user needs, business value, and roadmap for AI products, guiding their development and market fit.
# *   **AI Research (Apex):** Pushes the boundaries of AI, developing new algorithms, theories, and techniques to advance the field.

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain variable in python'
)
print(resp.text)
# Out:
# In Python, a **variable** is essentially a named storage location that holds a value. It's like a label or a tag that you attach to a piece of data in your computer's memory.
#
# Here's a breakdown of what variables are and how they work in Python:
#
# ---
#
# ### The Analogy: A Label, Not a Box
#
# Unlike some other programming languages where a variable might be thought of as a "box" that contains a value, in Python, it's more accurate to think of a variable as a **label or a name that refers to an object in memory.**
#
# When you create a variable, you're not putting data *into* the variable itself, but rather telling Python that this name (your variable) will now *point to* or *refer to* a specific data object in memory.
#
# ---
#
# ### How to Create and Use Variables
#
# You create a variable by simply assigning a value to a name using the assignment operator (`=`).
#
# **Syntax:**
#
# ```python
# variable_name = value
# ```
#
# **Examples:**
#
# ```python
# # Assigning an integer value
# age = 30
# print(age)  # Output: 30
#
# # Assigning a string value
# name = "Alice"
# print(name) # Output: Alice
#
# # Assigning a boolean value
# is_student = True
# print(is_student) # Output: True
#
# # Assigning a list value
# fruits = ["apple", "banana", "cherry"]
# print(fruits) # Output: ['apple', 'banana', 'cherry']
# ```
#
# ---
#
# ### Key Characteristics of Python Variables:
#
# 1.  **No Explicit Declaration:**
#     You don't need to declare the variable's type (like `int age;` or `String name;` in Java/C++). Python automatically determines the type based on the value you assign.
#
#     ```python
#     my_number = 10     # Python knows it's an integer
#     my_text = "Hello"  # Python knows it's a string
#     ```
#
# 2.  **Dynamic Typing:**
#     A variable's type can change during the program's execution. If you assign a different type of value to an existing variable, Python will update its reference to point to the new object, potentially of a different type.
#
#     ```python
#     x = 10       # x refers to an integer object
#     print(type(x)) # Output: <class 'int'>
#
#     x = "Python" # Now x refers to a string object
#     print(type(x)) # Output: <class 'str'>
#     ```
#
# 3.  **Variables as References (The Core Concept):**
#     When you assign a value to a variable, the variable doesn't *store* the value; it stores a *reference* (memory address) to the actual data object.
#
#     ```python
#     a = 5
#     b = a # Both 'a' and 'b' now refer to the same integer object '5' in memory
#
#     print(id(a)) # Get the memory address of the object 'a' refers to
#     print(id(b)) # Get the memory address of the object 'b' refers to
#     # Output will be the same memory address for both, e.g., 140736938974576
#
#     a = 10 # 'a' now refers to a NEW integer object '10'
#            # 'b' still refers to the original '5'
#
#     print(id(a)) # New memory address
#     print(id(b)) # Old memory address (still referring to 5)
#
#     print(a) # Output: 10
#     print(b) # Output: 5
#     ```
#     This behavior is crucial for understanding how Python handles objects and memory.
#
# 4.  **Variable Naming Rules:**
#     *   Must start with a letter (`a-z`, `A-Z`) or an underscore (`_`).
#     *   Cannot start with a number.
#     *   Can contain letters, numbers, and underscores.
#     *   Case-sensitive (`myVar` is different from `myvar`).
#     *   Cannot be a Python keyword (e.g., `if`, `else`, `while`, `for`, `print`).
#
#     **Good Practice:** Use `snake_case` (lowercase with underscores) for variable names (e.g., `first_name`, `total_price`).
#
# ---
#
# ### Why are Variables Important?
#
# *   **Store and Retrieve Data:** They allow you to hold data that your program needs to work with.
# *   **Make Code Readable:** Giving meaningful names to values makes your code much easier to understand. Imagine having `30` instead of `age` throughout your code!
# *   **Reuse Data:** You can use the same variable multiple times without retyping the value.
# *   **Flexibility:** You can change the value of a variable, allowing your program to react to different inputs or states.
#
# ---
#
# In essence, variables are fundamental building blocks in Python that allow you to manage and manipulate data effectively within your programs.
